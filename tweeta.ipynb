# %%
import twint

# Configure
c = twint.Config()

# %%
# import nest_asyncio
# nest_asyncio.apply()

# %%
# c.Username = "PrissyX6"
# Tobii6661
c.Username = str(input("Enter username: "))
# Out:
# Enter username: Tobii6661

# %%
# c.Search = "."
c.Limit = 20
c.Store_csv = True
c.Output = "tweets"

# %%
# Run
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-a70856039f52> in <module>
#       1 # Run
# ----> 2 twint.run.Search(c)
#
# c:\users\blaze\src\twint\twint\run.py in Search(config, callback)
#     279     config.Profile = False
#     280     config.Profile_full = False
# --> 281     run(config, callback)
#     282     if config.Pandas_au:
#     283         storage.panda._autoget("tweet")
#
# c:\users\blaze\src\twint\twint\run.py in run(config, callback)
#     200 def run(config, callback=None):
#     201     logme.debug(__name__+':run')
# --> 202     get_event_loop().run_until_complete(Twint(config).main(callback))
#     203
#     204 def Favorites(config):
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     569         future.add_done_callback(_run_until_complete_cb)
#     570         try:
# ...

# %%
import pandas as pd
data = pd.read_csv('tweets/tweets.csv')
data
# Out:
#                      id      conversation_id     created_at        date  \
# 0   1204356712028880897  1204356712028880897  1575975990000  2019-12-10
# 1   1204356600590409729  1204356600590409729  1575975964000  2019-12-10
# 2   1204356479165358080  1204356479165358080  1575975935000  2019-12-10
# 3   1204356330745745413  1204356330745745413  1575975899000  2019-12-10
# 4   1204352802178420737  1204352802178420737  1575975058000  2019-12-10
# 5   1204352762689007618  1204352762689007618  1575975049000  2019-12-10
# 6   1204352717709295616  1204352717709295616  1575975038000  2019-12-10
# 7   1204352687740981250  1204352687740981250  1575975031000  2019-12-10
# 8   1204352655776239616  1204352655776239616  1575975023000  2019-12-10
# 9   1204352582367490054  1204352582367490054  1575975006000  2019-12-10
# 10  1201980641803460608  1201980641803460608  1575409491000  2019-12-03
# 11  1201978636762583041  1201978636762583041  1575409013000  2019-12-03
# ...

# %%
import csv

keys = ["i am depressed", "i want to die", "commit suicide", "my death", "kill myself", "hang myself", "tired of life",
        "feel sorry","heart broken", "feel rejected", "feel frustrated", "feel sad", "feel lonely", "i will be gone",
        "end my life"]

unreal = ["just kidding", "playing", "not serious", "haha", "hahaha", "messing with you", "jokes", "lol", "lmao", "dwl",
          "lmfao", "guy", "guys", "someone", "he", "she", "they"]

alert = 0

with open("tweets/tweets.csv", "r", errors='ignore') as suicide:
    reader = csv.reader(suicide, delimiter=',')
    for lines in reader:
        line = lines[10].lower()
        for i in keys:
            if i in line:
                print(line)
                print(c.Username+" is being followed up...")
                alert += 1
                for k in unreal:
                    if k in line:
                        print(line)
                        print("Oops! "+c.Username+" might just be kidding...")
                        alert -= 1
                        break
        if alert > 3:
            print(c.Username+" is likely to commit suicide!")
            break
# Out:
# i will be gone to her place soon guys
# Tobii6661 is being followed up...
# i will be gone to her place soon guys
# Oops! Tobii6661 might just be kidding...
# she wants to commit suicide
# Tobii6661 is being followed up...
# she wants to commit suicide
# Oops! Tobii6661 might just be kidding...
# i feel frustrated, lol
# Tobii6661 is being followed up...
# i feel frustrated, lol
# Oops! Tobii6661 might just be kidding...
# i feel lonely
# Tobii6661 is being followed up...
